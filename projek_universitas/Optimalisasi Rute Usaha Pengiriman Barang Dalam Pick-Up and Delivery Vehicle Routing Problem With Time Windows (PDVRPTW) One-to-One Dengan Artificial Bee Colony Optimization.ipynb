# %%
# !pip install -e /srv/pkg/Hive.py
# Out:
# ERROR: /srv/pkg/Hive.py is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).

# %%
import math
try:
    import numpy as np
except:
    raise ImportError("Numpy module not installed.")

# %%
# !pip install beecolpy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for beecolpy: filename=beecolpy-2.3.2-py3-none-any.whl size=17964 sha256=2f40933792762ebcedb932cac0f040b96f0fe4cba3a9aa63d5a62760d7824390
#   Stored in directory: /root/.cache/pip/wheels/b4/f4/23/5c767b2476e5f2f3d3978b5c0bb5fab13884a3713150ece5dc
# Successfully built beecolpy
# ...

# %%
from beecolpy import abc

def sphere(x):
	total = 0
	for i in range(len(x)):
		total += x[i]**2
	return total

abc_obj = abc(sphere, [(-10,10), (-10,10)]) #Load data
abc_obj.fit() #Execute the algorithm
# Out:
# [-1.6035318623289604e-07, -1.1515454965954704e-07]

# %%
#If you want to get the obtained solution after execute the fit() method:
solution = abc_obj.get_solution()
solution
# Out:
# [-1.6035318623289604e-07, -1.1515454965954704e-07]

# %%
#If you want to get the number of iterations executed, number of times that
#scout event occur and number of times that NaN protection actuated:
iterations = abc_obj.get_status()
scout = abc_obj.get_status()
nan_events = abc_obj.get_status()

# %%
iterations
# Out:
# (50, 0, 0)

# %%
scout
# Out:
# (50, 0, 0)

# %%
nan_events
# Out:
# (50, 0, 0)

# %%
#If you want to get a list with position of all points (food sources) used in each iteration:
food_sources = abc_obj.get_agents()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-23-17470e72c499> in <cell line: 2>()
#       1 #If you want to get a list with position of all points (food sources) used in each iteration:
# ----> 2 food_sources = abc_obj.get_agents()
#
# /usr/local/lib/python3.10/dist-packages/beecolpy/beecolpy.py in get_agents(self, reset_agents)
#     323             next fit().
#     324         '''
# --> 325         assert self.log_agents, 'Food source logging disabled.'
#     326         self.reset_agents = reset_agents
#     327         return self.agents
#
# AssertionError: Food source logging disabled.

# %%
import numpy as np

# Fungsi objektif yang ingin dioptimalkan (contoh: fungsi sphere)
def objective_function(x):
    return sum(x**2)

# Fungsi untuk menghitung nilai fitness
def fitness(solution):
    return 1 / (1 + objective_function(solution))

# Inisialisasi populasi awal
def initialize_population(num_solutions, num_dimensions, min_value, max_value):
    return np.random.uniform(min_value, max_value, (num_solutions, num_dimensions))

# Memilih solusi yang akan dijadikan pekerja penjelajah
def select_exploratory_solution(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada solusi penjelajah
def explore_solution(solution, min_value, max_value):
    return solution + np.random.uniform(min_value, max_value, solution.shape)

# Evaluasi solusi penjelajah dan perbarui populasi
def update_population(population, solution, fitness):
    idx = np.argmax(fitness)
    population[idx] = solution
    return population

# Algoritma ABC
def artificial_bee_colony(num_iterations, num_solutions, num_dimensions, min_value, max_value):
    population = initialize_population(num_solutions, num_dimensions, min_value, max_value)
    for _ in range(num_iterations):
        for i, solution in enumerate(population):
            exploratory_solution = select_exploratory_solution(population)
            new_solution = explore_solution(exploratory_solution, min_value, max_value)
            new_fitness = fitness(new_solution)
            if new_fitness > fitness(solution):
                population[i] = new_solution
    best_solution_idx = np.argmax([fitness(solution) for solution in population])
    best_solution = population[best_solution_idx]
    return best_solution

# Pengaturan parameter
num_iterations = 100
num_solutions = 50
num_dimensions = 2
min_value = -10
max_value = 10

# Menjalankan algoritma ABC
best_solution = artificial_bee_colony(num_iterations, num_solutions, num_dimensions, min_value, max_value)
print("Solusi terbaik:", best_solution)
print("Nilai fitness:", fitness(best_solution))
# Out:
# Solusi terbaik: [ 0.1743089  -0.14149604]
# Nilai fitness: 0.9520139996686359

# %%
import numpy as np

# Fungsi objektif yang ingin dioptimalkan (contoh: fungsi sphere)
def objective_function(x):
    return sum(x**2)

# Fungsi untuk menghitung nilai fitness
def fitness(solution):
    return 1 / (1 + objective_function(solution))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_solutions, num_dimensions, min_value, max_value):
    population = np.random.uniform(min_value, max_value, (num_solutions, num_dimensions))
    fitness_values = np.array([fitness(solution) for solution in population])
    return population, fitness_values

# Memilih solusi yang akan dijadikan pekerja penjelajah
def select_exploratory_solution(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada solusi penjelajah
def explore_solution(solution, min_value, max_value):
    return solution + np.random.uniform(min_value, max_value, solution.shape)

# Evaluasi solusi penjelajah dan perbarui populasi
def update_population(population, solution, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = solution
    fitness_values[idx] = fitness(solution)
    return population, fitness_values

# Algoritma ABC
def artificial_bee_colony(num_iterations, num_solutions, num_dimensions, min_value, max_value):
    population, fitness_values = initialize_population(num_solutions, num_dimensions, min_value, max_value)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, solution in enumerate(population):
            exploratory_solution = select_exploratory_solution(population)
            new_solution = explore_solution(exploratory_solution, min_value, max_value)
            new_fitness = fitness(new_solution)
            if new_fitness > fitness_values[i]:
                population[i] = new_solution
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_solution_idx = np.argmax(fitness_values)
    best_solution = population[best_solution_idx]
    return best_solution

# Pengaturan parameter
num_iterations = 100
num_solutions = 50
num_dimensions = 2
min_value = -10
max_value = 10

# Menjalankan algoritma ABC
best_solution = artificial_bee_colony(num_iterations, num_solutions, num_dimensions, min_value, max_value)
print("\nSolusi Terbaik:", best_solution)
print("Nilai Fitness Solusi Terbaik:", fitness(best_solution))
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.00841294 0.02053358 0.09917784 0.01628303 0.02276391 0.02182676
#  0.00801524 0.0189057  0.21047848 0.00652532 0.01847894 0.00758956
#  0.01094611 0.01085447 0.00751265 0.01577523 0.01401574 0.01085002
#  0.07898011 0.01404739 0.04755601 0.83007716 0.01009816 0.01300398
#  0.00975785 0.02745093 0.00966012 0.0186135  0.03143126 0.02330304
#  0.0209915  0.04202901 0.01278125 0.01587047 0.01581426 0.01030334
#  0.03413162 0.08620828 0.06462595 0.18216064 0.01077168 0.02494291
#  0.34303248 0.02500407 0.00675107 0.00576792 0.01196049 0.06399589
#  0.04449983 0.09749444]
# Iterasi 100 - Nilai Fitness:
# [0.48147078 0.90713803 0.93079845 0.69996462 0.39322599 0.40886764
#  0.28758923 0.30345705 0.47444711 0.25038691 0.32321199 0.81488446
#  0.71782625 0.96659941 0.44366468 0.31509964 0.42376217 0.67215017
#  0.4228366  0.22530424 0.63577426 0.83007716 0.66361571 0.98680521
#  0.17880285 0.20464369 0.35091225 0.42458915 0.92319678 0.88962983
# ...

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route

# Pengaturan parameter
num_iterations = 1000
num_routes = 50
num_locations = 10
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.20534765 0.16079571 0.17779135 0.15773946 0.17272348 0.16083643
#  0.20132072 0.19625217 0.18697774 0.1449998  0.1749169  0.17151834
#  0.16039297 0.17757449 0.18523633 0.20041555 0.17369364 0.18927662
#  0.16469831 0.19747954 0.1739292  0.17846307 0.16896639 0.20412782
#  0.16955763 0.20103224 0.17537206 0.15277762 0.18617277 0.16372206
#  0.19522883 0.15382736 0.18077342 0.16357598 0.17984058 0.16034295
#  0.1824728  0.16189043 0.15120837 0.1966163  0.19247174 0.14552877
#  0.1723038  0.19999683 0.14365889 0.16789419 0.18798158 0.20954198
#  0.15343396 0.19026754]
# Iterasi 100 - Nilai Fitness:
# [0.23014601 0.2302013  0.23666985 0.22260628 0.23700044 0.21331518
#  0.23442166 0.23232392 0.22259984 0.21705745 0.23740294 0.2334644
#  0.22250495 0.21555387 0.23595473 0.22607563 0.22004358 0.23157311
#  0.22451272 0.22116736 0.22058265 0.23308534 0.22254615 0.23523062
#  0.22247685 0.23648175 0.22144094 0.2367783  0.22322242 0.21389186
# ...

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route

# Pengaturan parameter
num_iterations = 1000
num_routes = 4  # Jumlah kendaraan
num_locations = 10  # Jumlah simpul
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.14224963 0.14532454 0.15412409 0.1671649 ]
# Iterasi 100 - Nilai Fitness:
# [0.21562432 0.20372212 0.18655414 0.20850323]
# Iterasi 200 - Nilai Fitness:
# [0.21562432 0.20372212 0.22541215 0.21506158]
# Iterasi 300 - Nilai Fitness:
# [0.21562432 0.21975871 0.22541215 0.21704529]
# Iterasi 400 - Nilai Fitness:
# [0.21562432 0.21975871 0.22541215 0.21704529]
# Iterasi 500 - Nilai Fitness:
# [0.22153332 0.21975871 0.22541215 0.22192818]
# Iterasi 600 - Nilai Fitness:
# [0.22153332 0.21975871 0.22883714 0.22192818]
# Iterasi 700 - Nilai Fitness:
# [0.22153332 0.21975871 0.22883714 0.22192818]
# Iterasi 800 - Nilai Fitness:
# [0.22153332 0.2229198  0.22883714 0.22192818]
# Iterasi 900 - Nilai Fitness:
# [0.22153332 0.2229198  0.22883714 0.22192818]
# Iterasi 1000 - Nilai Fitness:
# [0.22153332 0.2229198  0.22883714 0.22192818]
#
# Rute Terbaik: [8 0 6 1 4 7 3 9 5 2]
# Total Jarak Tempuh Rute Terbaik: 3.3699199932629376

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route, population

# Pengaturan parameter
num_iterations = 500
num_routes = 4  # Jumlah kendaraan
num_locations = 10  # Jumlah simpul
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

# Menampilkan rute terbaik yang dilalui setiap kendaraan
print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.14400992 0.16549317 0.13882926 0.17131793]
# Iterasi 100 - Nilai Fitness:
# [0.22182826 0.24134601 0.21036164 0.20086243]
# Iterasi 200 - Nilai Fitness:
# [0.22182826 0.24134601 0.23056726 0.23406357]
# Iterasi 300 - Nilai Fitness:
# [0.22182826 0.24134601 0.23056726 0.23406357]
# Iterasi 400 - Nilai Fitness:
# [0.228483   0.24134601 0.23056726 0.23406357]
# Iterasi 500 - Nilai Fitness:
# [0.228483   0.24134601 0.23056726 0.23406357]
#
# Rute Terbaik: [0 3 5 1 7 8 4 6 9 2]
# Total Jarak Tempuh Rute Terbaik: 3.1434287244166272
#
# Rute Terbaik Setiap Kendaraan:
# Kendaraan 1: [3 6 2 9 0 4 5 8 7 1], Total Jarak Tempuh: 3.376693215339771
# Kendaraan 2: [0 3 5 1 7 8 4 6 9 2], Total Jarak Tempuh: 3.1434287244166272
# Kendaraan 3: [3 0 8 1 7 5 4 9 6 2], Total Jarak Tempuh: 3.3371291751069814
# Kendaraan 4: [2 9 6 4 5 7 8 1 3 0], Total Jarak Tempuh: 3.2723436894955946

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(range(1, num_locations)) for _ in range(num_routes)]  # Menghindari node depot (0)
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Menambahkan node depot sebagai node pertama dan terakhir setiap rute
def add_depot_to_route(route):
    return np.insert(route, 0, 0)  # Node depot pada posisi pertama

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route

# Pengaturan parameter
num_iterations = 1000
num_routes = 4  # Jumlah kendaraan
num_locations = 10  # Jumlah simpul
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
best_route_with_depot = add_depot_to_route(best_route)  # Tambahkan node depot
print("\nRute Terbaik:", best_route_with_depot)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route_with_depot, locations))
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.20266266 0.22572294 0.17472591 0.18767007]
# Iterasi 100 - Nilai Fitness:
# [0.23691609 0.2700056  0.23435732 0.24606835]
# Iterasi 200 - Nilai Fitness:
# [0.24416875 0.2700056  0.2506475  0.24906042]
# Iterasi 300 - Nilai Fitness:
# [0.24878715 0.2700056  0.25542391 0.24906042]
# Iterasi 400 - Nilai Fitness:
# [0.26081349 0.2700056  0.25542391 0.25948748]
# Iterasi 500 - Nilai Fitness:
# [0.26081349 0.2700056  0.25947769 0.25948748]
# Iterasi 600 - Nilai Fitness:
# [0.26081349 0.2700056  0.25947769 0.25948748]
# Iterasi 700 - Nilai Fitness:
# [0.26081349 0.2700056  0.27135688 0.25948748]
# Iterasi 800 - Nilai Fitness:
# [0.26081349 0.2700056  0.27135688 0.25948748]
# Iterasi 900 - Nilai Fitness:
# [0.26081349 0.2700056  0.27135688 0.25948748]
# Iterasi 1000 - Nilai Fitness:
# [0.26081349 0.2700056  0.27135688 0.27437207]
#
# Rute Terbaik: [0 8 4 9 3 1 5 7 2 6]
# Total Jarak Tempuh Rute Terbaik: 4.014914325618221

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(range(1, num_locations)) for _ in range(num_routes)]  # Menghindari node depot (0)
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Menambahkan node depot sebagai node terakhir setiap rute
def add_depot_to_route(route):
    return np.append(route, 0)  # Node depot pada posisi terakhir

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route

# Pengaturan parameter
num_iterations = 1000
num_routes = 4  # Jumlah kendaraan
num_locations = 10  # Jumlah simpul
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
best_route_with_depot = add_depot_to_route(best_route)  # Tambahkan node depot
print("\nRute Terbaik:", best_route_with_depot)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route_with_depot, locations))
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.15034827 0.15854212 0.15862962 0.14628199]
# Iterasi 100 - Nilai Fitness:
# [0.24427205 0.20664999 0.20592105 0.20860354]
# Iterasi 200 - Nilai Fitness:
# [0.24427205 0.21929195 0.21375629 0.24427205]
# Iterasi 300 - Nilai Fitness:
# [0.24427205 0.21929195 0.21965049 0.24427205]
# Iterasi 400 - Nilai Fitness:
# [0.24427205 0.21929195 0.21965049 0.24427205]
# Iterasi 500 - Nilai Fitness:
# [0.24427205 0.22725008 0.21965049 0.24427205]
# Iterasi 600 - Nilai Fitness:
# [0.24427205 0.22725008 0.21965049 0.248222  ]
# Iterasi 700 - Nilai Fitness:
# [0.24427205 0.22725008 0.21965049 0.248222  ]
# Iterasi 800 - Nilai Fitness:
# [0.24427205 0.22725008 0.21965049 0.248222  ]
# Iterasi 900 - Nilai Fitness:
# [0.24427205 0.22725008 0.22487902 0.248222  ]
# Iterasi 1000 - Nilai Fitness:
# [0.24427205 0.22725008 0.22487902 0.248222  ]
#
# Rute Terbaik: [9 3 1 2 5 7 4 6 8 0]
# Total Jarak Tempuh Rute Terbaik: 4.3701327246300075

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(range(1, num_locations)) for _ in range(num_routes)]  # Menghindari node depot (0)
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Menambahkan node depot sebagai node pertama dan terakhir setiap rute
def add_depot_to_route(route):
    return np.insert(route, 0, 0)  # Node depot pada posisi pertama

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route

# Pengaturan parameter
num_iterations = 1000
num_routes = 4  # Jumlah kendaraan
num_locations = 10  # Jumlah simpul
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
best_route_with_depot = add_depot_to_route(best_route)  # Tambahkan node depot
print("\nRute Terbaik:", best_route_with_depot)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route_with_depot, locations))
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.17163772 0.1791075  0.16761694 0.17137724]
# Iterasi 100 - Nilai Fitness:
# [0.21014389 0.2175242  0.20751348 0.20819975]
# Iterasi 200 - Nilai Fitness:
# [0.22164751 0.2175242  0.21268023 0.22202269]
# Iterasi 300 - Nilai Fitness:
# [0.22164751 0.2175242  0.22649817 0.22202269]
# Iterasi 400 - Nilai Fitness:
# [0.22164751 0.22266786 0.22649817 0.22417438]
# Iterasi 500 - Nilai Fitness:
# [0.22528067 0.22266786 0.22649817 0.24800739]
# Iterasi 600 - Nilai Fitness:
# [0.22731515 0.22266786 0.22649817 0.24800739]
# Iterasi 700 - Nilai Fitness:
# [0.22731515 0.22266786 0.22892689 0.24800739]
# Iterasi 800 - Nilai Fitness:
# [0.22731515 0.22266786 0.22892689 0.24800739]
# Iterasi 900 - Nilai Fitness:
# [0.22731515 0.22266786 0.238597   0.24800739]
# Iterasi 1000 - Nilai Fitness:
# [0.22731515 0.23570324 0.238597   0.24800739]
#
# Rute Terbaik: [0 4 5 2 6 9 1 7 8 3]
# Total Jarak Tempuh Rute Terbaik: 3.9473718987151303

# %%
best_route_with_depot = add_depot_to_route(best_route)  # Tambahkan node depot
if best_route_with_depot[-1] == 0:
    print("Rute berakhir di node depot (0)")
else:
    print("Rute tidak berakhir di node depot (0)")
# Out:
# Rute tidak berakhir di node depot (0)

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(range(1, num_locations)) for _ in range(num_routes)]  # Menghindari node depot (0)
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Menambahkan dua node depot sebagai node awal dan akhir setiap rute
def add_depots_to_route(route):
    route_with_depot = np.insert(route, 0, 0)  # Node depot pertama pada posisi pertama
    route_with_depot = np.append(route_with_depot, 10)  # Node depot kedua pada posisi terakhir
    return route_with_depot


# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route

# Pengaturan parameter
num_iterations = 1000
num_routes = 4  # Jumlah kendaraan
num_locations = 11  # Jumlah simpul
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
best_route_with_depots = add_depots_to_route(best_route)  # Tambahkan dua node depot
print("\nRute Terbaik:", best_route_with_depots)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route_with_depots, locations))
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.16570968 0.18717953 0.16727813 0.17378903]
# Iterasi 100 - Nilai Fitness:
# [0.24154513 0.26604339 0.23803955 0.25308948]
# Iterasi 200 - Nilai Fitness:
# [0.28694489 0.26604339 0.24761493 0.25308948]
# Iterasi 300 - Nilai Fitness:
# [0.28694489 0.26604339 0.24761493 0.25308948]
# Iterasi 400 - Nilai Fitness:
# [0.28694489 0.26604339 0.24761493 0.25308948]
# Iterasi 500 - Nilai Fitness:
# [0.28694489 0.26604339 0.24933146 0.25308948]
# Iterasi 600 - Nilai Fitness:
# [0.28694489 0.26604339 0.24933146 0.25308948]
# Iterasi 700 - Nilai Fitness:
# [0.28694489 0.26604339 0.24933146 0.26743549]
# Iterasi 800 - Nilai Fitness:
# [0.28694489 0.26604339 0.24933146 0.26743549]
# Iterasi 900 - Nilai Fitness:
# [0.28694489 0.26604339 0.24933146 0.26743549]
# Iterasi 1000 - Nilai Fitness:
# [0.28694489 0.26604339 0.24933146 0.26743549]
#
# Rute Terbaik: [ 0 10  2  6  1  8  7  5  3  4  9 10]
# Total Jarak Tempuh Rute Terbaik: 3.6155144639792165

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(range(1, num_locations - 1)) for _ in range(num_routes)]  # Hindari node depot (0 dan 10)
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Menambahkan dua node depot sebagai node awal dan akhir setiap rute
def add_depots_to_route(route):
    route_with_depots = np.insert(route, 0, 0)  # Node depot pertama pada posisi pertama
    route_with_depots = np.append(route_with_depots, 10)  # Node depot kedua pada posisi terakhir
    return route_with_depots

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    new_route = np.copy(route)
    random_index = np.random.randint(1, len(route) - 1)  # Hindari node depot (0 dan 10)
    new_route[random_index] = np.random.randint(1, num_locations - 1)
    return new_route

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    new_fitness = fitness(route, locations)
    if new_fitness > np.min(fitness_values):
        idx = np.argmin(fitness_values)
        population[idx] = route
        fitness_values[idx] = new_fitness
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route

# Pengaturan parameter
num_iterations = 1000
num_routes = 4  # Jumlah kendaraan
num_locations = 11  # Jumlah simpul (termasuk dua node depot)
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
best_route_with_depots = add_depots_to_route(best_route)  # Tambahkan dua node depot
print("\nRute Terbaik:", best_route_with_depots)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route_with_depots, locations))
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.19255149 0.18772623 0.17795408 0.17763265]
# Iterasi 100 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 200 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 300 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 400 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 500 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 600 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 700 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 800 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 900 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
# Iterasi 1000 - Nilai Fitness:
# [0.61913174 0.61913174 0.61913174 0.61913174]
#
# Rute Terbaik: [ 0  5  5  5  2  2  5  5  5  7 10]
# Total Jarak Tempuh Rute Terbaik: 1.73842743455489

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = []
    for _ in range(num_routes):
        route = list(range(1, num_locations - 1))  # Simpul yang tersedia untuk dipilih
        for i in range(1, num_locations - 2):  # Hindari node depot (0 dan 10)
            np.random.shuffle(route)  # Acak urutan simpul
            route_with_depots = [0] + route[:i] + [10]  # Tambahkan node depot
            population.append(route_with_depots)
            break  # Keluar dari loop setelah menambahkan rute dengan simpul yang berbeda
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values


# Menambahkan dua node depot sebagai node awal dan akhir setiap rute
def add_depots_to_route(route):
    route_with_depots = np.insert(route, 0, 0)  # Node depot pertama pada posisi pertama
    route_with_depots = np.append(route_with_depots, 10)  # Node depot kedua pada posisi terakhir
    return route_with_depots

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    route = population[np.random.randint(0, len(population))]
    while 0 in route or 10 in route:
        route = population[np.random.randint(0, len(population))]
    return route

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    new_route = np.copy(route)
    random_index = np.random.randint(1, len(route) - 1)  # Hindari node depot (0 dan 10)
    new_route[random_index] = np.random.randint(1, num_locations - 1)
    return new_route

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    new_fitness = fitness(route, locations)
    if new_fitness > np.min(fitness_values):
        idx = np.argmin(fitness_values)
        population[idx] = route
        fitness_values[idx] = new_fitness
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route, population

# Pengaturan parameter
num_iterations = 1000
num_routes = 4  # Jumlah kendaraan
num_locations = 11  # Jumlah simpul (termasuk dua node depot)
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route, population = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
best_route_with_depots = add_depots_to_route(best_route)  # Tambahkan dua node depot
print("\nRute Terbaik:", best_route_with_depots)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route_with_depots, locations))

# Tampilkan rute terbaik untuk setiap kendaraan
print("\nRute Terbaik untuk Setiap Kendaraan:")
for i, route in enumerate(population):
    route_with_depots = add_depots_to_route(route)
    print(f"Kendaraan {i+1}: {route_with_depots}, Total Jarak Tempuh: {objective_function(route_with_depots, locations)}")
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.42750577 0.42185041 0.50159571 0.42750577]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-a54fbe8ca655> in <cell line: 88>()
#      86
#      87 # Menjalankan algoritma ABC untuk VRP
# ---> 88 best_route, population = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
#      89 best_route_with_depots = add_depots_to_route(best_route)  # Tambahkan dua node depot
#      90 print("\nRute Terbaik:", best_route_with_depots)
#
# <ipython-input-24-a54fbe8ca655> in artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
#      66     for iteration in range(num_iterations):
#      67         for i, route in enumerate(population):
# ---> 68             exploratory_route = select_exploratory_route(population)
#      69             new_route = explore_route(exploratory_route)
# ...

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    return np.random.permutation(route)

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route, population

# Pengaturan parameter
num_iterations = 500
num_routes = 4  # Jumlah kendaraan
num_locations = 10  # Jumlah simpul
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

# Menampilkan rute terbaik yang dilalui setiap kendaraan
print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.16110944 0.18437262 0.15815244 0.13579531]
# Iterasi 100 - Nilai Fitness:
# [0.19759208 0.21365891 0.19129809 0.20681453]
# Iterasi 200 - Nilai Fitness:
# [0.21423546 0.22007675 0.20777222 0.20681453]
# Iterasi 300 - Nilai Fitness:
# [0.21423546 0.22007675 0.21679332 0.20681453]
# Iterasi 400 - Nilai Fitness:
# [0.21423546 0.22007675 0.2251871  0.20681453]
# Iterasi 500 - Nilai Fitness:
# [0.21423546 0.22007675 0.2251871  0.20681453]
#
# Rute Terbaik: [3 0 9 2 7 5 4 8 1 6]
# Total Jarak Tempuh Rute Terbaik: 3.4407516231610313
#
# Rute Terbaik Setiap Kendaraan:
# Kendaraan 1: [4 6 1 2 9 0 3 8 5 7], Total Jarak Tempuh: 3.6677613630751713
# Kendaraan 2: [8 3 0 1 6 9 2 7 5 4], Total Jarak Tempuh: 3.5438694405745035
# Kendaraan 3: [3 0 9 2 7 5 4 8 1 6], Total Jarak Tempuh: 3.4407516231610313
# Kendaraan 4: [1 6 2 4 8 5 7 0 3 9], Total Jarak Tempuh: 3.835250164578091

# %%
import numpy as np

# Fungsi untuk menghitung jarak antara dua titik (misalnya jarak Euclidean)
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# Fungsi objektif yang ingin dioptimalkan (misalnya total jarak tempuh dalam VRP)
def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

# Fungsi untuk menghitung nilai fitness (misalnya meminimalkan total jarak tempuh)
def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

# Inisialisasi populasi awal dan nilai fitness
def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

# Memilih rute yang akan dijadikan pekerja penjelajah
def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

# Fase penjelajahan: Melakukan modifikasi pada rute penjelajah
def explore_route(route):
    new_route = np.copy(route)
    idx1, idx2 = np.random.choice(range(1, len(route) - 1), size=2, replace=False)
    new_route[idx1], new_route[idx2] = new_route[idx2], new_route[idx1]
    return new_route

# Evaluasi rute penjelajah dan perbarui populasi
def update_population(population, route, fitness_values):
    new_fitness = fitness(route, locations)
    min_idx = np.argmin(fitness_values)
    if new_fitness > fitness_values[min_idx]:
        population[min_idx] = route
        fitness_values[min_idx] = new_fitness
    return population, fitness_values

# Algoritma ABC untuk VRP
def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population, fitness_values = update_population(population, new_route, fitness_values)
        if (iteration + 1) % 100 == 0:  # Cetak nilai fitness setiap 100 iterasi
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmax(fitness_values)
    best_route = population[best_route_idx]
    return best_route, population

# Pengaturan parameter
num_iterations = 500
num_routes = 4  # Jumlah kendaraan
num_locations = 10  # Jumlah simpul
locations = np.random.rand(num_locations, 2)  # Generate random locations

# Menjalankan algoritma ABC untuk VRP
best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

# Menampilkan rute terbaik yang dilalui setiap kendaraan
print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.1294942  0.15956219 0.18633678 0.15252502]
# Iterasi 100 - Nilai Fitness:
# [0.23053943 0.23053943 0.23053943 0.23053943]
# Iterasi 200 - Nilai Fitness:
# [0.23053943 0.23053943 0.23053943 0.23053943]
# Iterasi 300 - Nilai Fitness:
# [0.23053943 0.23053943 0.23053943 0.23053943]
# Iterasi 400 - Nilai Fitness:
# [0.23053943 0.23053943 0.23053943 0.23053943]
# Iterasi 500 - Nilai Fitness:
# [0.23053943 0.23053943 0.23053943 0.23053943]
#
# Rute Terbaik: [8 5 6 3 0 2 9 1 7 4]
# Total Jarak Tempuh Rute Terbaik: 3.337652727804225
#
# Rute Terbaik Setiap Kendaraan:
# Kendaraan 1: [8 5 6 3 0 2 9 1 7 4], Total Jarak Tempuh: 3.337652727804225
# Kendaraan 2: [8 5 6 3 0 2 9 1 7 4], Total Jarak Tempuh: 3.337652727804225
# Kendaraan 3: [8 5 6 3 0 2 9 1 7 4], Total Jarak Tempuh: 3.337652727804225
# Kendaraan 4: [8 5 6 3 0 2 9 1 7 4], Total Jarak Tempuh: 3.337652727804225

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    total_distance += distance(locations[route[-1]], locations[route[0]])  # Kembali ke titik awal
    return total_distance

def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations - 1) for _ in range(num_routes)]  # Hapus titik awal dari permutasi
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, fitness_values):
    idx = np.argmax(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    best_fitness = 0
    best_route = None

    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)

    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
                # Memperbarui rute terbaik jika ditemukan rute yang lebih baik
                if new_fitness > best_fitness:
                    best_fitness = new_fitness
                    best_route = new_route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)

    # Jika tidak ada rute terbaik sebelumnya, pilih dari populasi awal
    if best_route is None:
        best_route_idx = np.argmax(fitness_values)
        best_route = population[best_route_idx]
        best_fitness = fitness_values[best_route_idx]

    return best_route, population



num_iterations = 500
num_routes = 4
num_locations = 10
locations = np.random.rand(num_locations, 2)

best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {np.insert(route, 0, 0)}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.20232287 0.20064518 0.24600548 0.20960065]
# Iterasi 100 - Nilai Fitness:
# [0.3062011  0.28456246 0.2994909  0.28131276]
# Iterasi 200 - Nilai Fitness:
# [0.3062011  0.28989643 0.30653276 0.31160195]
# Iterasi 300 - Nilai Fitness:
# [0.3062011  0.30826588 0.30653276 0.31160195]
# Iterasi 400 - Nilai Fitness:
# [0.3062011  0.30826588 0.30653276 0.31160195]
# Iterasi 500 - Nilai Fitness:
# [0.30654467 0.30826588 0.30653276 0.31160195]
#
# Rute Terbaik: [5 4 3 0 1 8 7 2 6]
# Total Jarak Tempuh Rute Terbaik: 2.209222487651424
#
# Rute Terbaik Setiap Kendaraan:
# Kendaraan 1: [0 2 6 7 5 4 1 0 3 8], Total Jarak Tempuh: 2.262167301112398
# Kendaraan 2: [0 5 3 0 1 4 8 7 6 2], Total Jarak Tempuh: 2.2439529147598445
# Kendaraan 3: [0 2 6 7 8 1 3 0 5 4], Total Jarak Tempuh: 2.2622940184273572
# Kendaraan 4: [0 5 4 3 0 1 8 7 2 6], Total Jarak Tempuh: 2.209222487651424

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    return total_distance

def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, fitness_values):
    idx = np.argmin(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    best_route_idx = np.argmin(fitness_values)
    best_route = population[best_route_idx]
    return best_route, population

num_iterations = 500
num_routes = 4
num_locations = 10
locations = np.random.rand(num_locations, 2)

best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.16292895 0.22168055 0.1782193  0.16873283]
# Iterasi 100 - Nilai Fitness:
# [0.21710387 0.23670825 0.23805931 0.21038246]
# Iterasi 200 - Nilai Fitness:
# [0.22499056 0.24667326 0.23805931 0.2366358 ]
# Iterasi 300 - Nilai Fitness:
# [0.23350237 0.24667326 0.24618421 0.2366358 ]
# Iterasi 400 - Nilai Fitness:
# [0.23350237 0.24667326 0.24618421 0.23727825]
# Iterasi 500 - Nilai Fitness:
# [0.23350237 0.24667326 0.24618421 0.23727825]
#
# Rute Terbaik: [8 6 4 0 7 3 1 9 5 2]
# Total Jarak Tempuh Rute Terbaik: 3.282611775775052
#
# Rute Terbaik Setiap Kendaraan:
# Kendaraan 1: [8 6 4 0 7 3 1 9 5 2], Total Jarak Tempuh: 3.282611775775052
# Kendaraan 2: [9 2 1 6 4 3 7 0 8 5], Total Jarak Tempuh: 3.0539456232152338
# Kendaraan 3: [7 3 4 0 8 6 2 9 1 5], Total Jarak Tempuh: 3.0619989962013685
# Kendaraan 4: [3 7 0 2 9 5 1 6 8 4], Total Jarak Tempuh: 3.2144613287519794

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    return total_distance

def fitness(route, locations):
    return 1 / (1 + objective_function(route, locations))

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    fitness_values = np.array([fitness(route, locations) for route in population])
    return population, fitness_values

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, fitness_values):
    idx = np.argmin(fitness_values)
    population[idx] = route
    fitness_values[idx] = fitness(route, locations)
    return population, fitness_values

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population, fitness_values = initialize_population(num_routes, num_locations)
    print("Iterasi 0 - Nilai Fitness Populasi Awal:")
    print(fitness_values)
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            new_fitness = fitness(new_route, locations)
            if new_fitness > fitness_values[i]:
                population[i] = new_route
                fitness_values[i] = new_fitness
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1} - Nilai Fitness:")
            print(fitness_values)
    sorted_routes_indices = np.argsort(fitness_values)
    best_route_idx = sorted_routes_indices[0]
    best_route = population[best_route_idx]
    return best_route, population

num_iterations = 500
num_routes = 4
num_locations = 10
locations = np.random.rand(num_locations, 2)

best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 0 - Nilai Fitness Populasi Awal:
# [0.14395158 0.13971178 0.15327657 0.1789602 ]
# Iterasi 100 - Nilai Fitness:
# [0.19899289 0.22015125 0.23300535 0.19658914]
# Iterasi 200 - Nilai Fitness:
# [0.24277939 0.22015125 0.23300535 0.20109955]
# Iterasi 300 - Nilai Fitness:
# [0.24277939 0.22015125 0.23300535 0.21136644]
# Iterasi 400 - Nilai Fitness:
# [0.24277939 0.22015125 0.23300535 0.21754484]
# Iterasi 500 - Nilai Fitness:
# [0.24277939 0.22015125 0.23300535 0.21754484]
#
# Rute Terbaik: [5 6 3 1 2 4 8 9 7 0]
# Total Jarak Tempuh Rute Terbaik: 3.5967534004289994
#
# Rute Terbaik Setiap Kendaraan:
# Kendaraan 1: [7 0 9 8 4 3 6 1 5 2], Total Jarak Tempuh: 3.1189657762873453
# Kendaraan 2: [7 0 9 6 8 3 4 2 5 1], Total Jarak Tempuh: 3.5423317207965805
# Kendaraan 3: [4 8 1 3 6 9 7 0 2 5], Total Jarak Tempuh: 3.291746865884124
# Kendaraan 4: [5 6 3 1 2 4 8 9 7 0], Total Jarak Tempuh: 3.5967534004289994

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations):
    new_fitness = objective_function(route, locations)
    worst_idx = np.argmax([objective_function(p, locations) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1} - Total Jarak Tempuh Rute Terbaik: {best_distance}")
    return best_route, population

num_iterations = 500
num_routes = 4
num_locations = 10
locations = np.random.rand(num_locations, 2)

best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 100 - Total Jarak Tempuh Rute Terbaik: 1.8181661750136977
# Iterasi 200 - Total Jarak Tempuh Rute Terbaik: 1.8181661750136977
# Iterasi 300 - Total Jarak Tempuh Rute Terbaik: 1.8181661750136977
# Iterasi 400 - Total Jarak Tempuh Rute Terbaik: 1.8181661750136977
# Iterasi 500 - Total Jarak Tempuh Rute Terbaik: 1.8181661750136977
#
# Rute Terbaik: [0 4 2 9 5 6 3 1 7 8]
# Total Jarak Tempuh Rute Terbaik: 1.8181661750136977
#
# Rute Terbaik Setiap Kendaraan:
# Kendaraan 1: [5 9 6 3 2 4 0 8 7 1], Total Jarak Tempuh: 2.0191869225938373
# Kendaraan 2: [9 6 5 7 3 1 2 8 0 4], Total Jarak Tempuh: 2.144669951088729
# Kendaraan 3: [3 8 4 1 2 0 9 5 7 6], Total Jarak Tempuh: 3.7493448327545167
# Kendaraan 4: [0 4 2 9 5 6 3 1 7 8], Total Jarak Tempuh: 1.8181661750136977

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations):
    new_fitness = objective_function(route, locations)
    worst_idx = np.argmax([objective_function(p, locations) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
          best_fitness = objective_function(best_route, locations)
          print(f"Iterasi {iteration + 1} - Nilai Fitness Rute Terbaik: {best_fitness}")

    return best_route, population

num_iterations = 500
num_routes = 4
num_locations = 10
locations = np.random.rand(num_locations, 2)

best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 100 - Nilai Fitness Rute Terbaik: 3.0440962540079988
# Iterasi 200 - Nilai Fitness Rute Terbaik: 2.804294635564081
# Iterasi 300 - Nilai Fitness Rute Terbaik: 2.804294635564081
# Iterasi 400 - Nilai Fitness Rute Terbaik: 2.804294635564081
# Iterasi 500 - Nilai Fitness Rute Terbaik: 2.804294635564081
#
# Rute Terbaik: [1 8 4 5 0 6 3 7 2 9]
# Total Jarak Tempuh Rute Terbaik: 2.804294635564081
#
# Rute Terbaik Setiap Kendaraan:
# Kendaraan 1: [7 3 1 9 2 8 5 0 4 6], Total Jarak Tempuh: 3.2304017343385825
# Kendaraan 2: [5 8 9 0 4 6 7 1 2 3], Total Jarak Tempuh: 4.896580675199191
# Kendaraan 3: [6 3 8 4 5 0 7 2 9 1], Total Jarak Tempuh: 3.0440962540079988
# Kendaraan 4: [1 8 4 5 0 6 3 7 2 9], Total Jarak Tempuh: 2.804294635564081

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations):
    new_fitness = objective_function(route, locations)
    worst_idx = np.argmax([objective_function(p, locations) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations)
                print(f"Kendaraan {idx+1}: Nilai Fitness = {route_distance}")
    return best_route, population

num_iterations = 500
num_routes = 4
num_locations = 10
locations = np.random.rand(num_locations, 2)

best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations))

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations)}")
# Out:
# Iterasi 100:
# Kendaraan 1: Nilai Fitness = 2.972873324971891
# Kendaraan 2: Nilai Fitness = 2.9793514541479555
# Kendaraan 3: Nilai Fitness = 2.822709567551692
# Kendaraan 4: Nilai Fitness = 4.4150375519152885
# Iterasi 200:
# Kendaraan 1: Nilai Fitness = 5.75375453860672
# Kendaraan 2: Nilai Fitness = 2.4292711193171748
# Kendaraan 3: Nilai Fitness = 2.822709567551692
# Kendaraan 4: Nilai Fitness = 2.971278823267843
# Iterasi 300:
# Kendaraan 1: Nilai Fitness = 3.9763189519903124
# Kendaraan 2: Nilai Fitness = 2.4292711193171748
# Kendaraan 3: Nilai Fitness = 2.822709567551692
# Kendaraan 4: Nilai Fitness = 2.971278823267843
# Iterasi 400:
# Kendaraan 1: Nilai Fitness = 2.2759003413433243
# Kendaraan 2: Nilai Fitness = 2.4292711193171748
# Kendaraan 3: Nilai Fitness = 4.675330745798816
# Kendaraan 4: Nilai Fitness = 2.786765879177889
# Iterasi 500:
# Kendaraan 1: Nilai Fitness = 2.2759003413433243
# Kendaraan 2: Nilai Fitness = 2.4292711193171748
# ...

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    # Menambahkan jarak kembali ke depot
    total_distance += distance(locations[route[-1]], locations[route[0]])
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations - 1) + 1 for _ in range(num_routes)]  # Hindari depot di awal
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations):
    new_fitness = objective_function(route, locations)
    worst_idx = np.argmax([objective_function(p, locations) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations)
                print(f"Kendaraan {idx+1}: Nilai Fitness = {route_distance}")
    return best_route, population

num_iterations = 500
num_routes = 4
num_locations = 11
locations = np.random.rand(num_locations, 2)

best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)
print("\nRute Terbaik:", [0] + best_route.tolist() + [0])  # Menambahkan depot di awal dan akhir rute
best_distance = objective_function([0] + best_route.tolist() + [0], locations)  # Menghitung total jarak termasuk kembali ke depot
print("Total Jarak Tempuh Rute Terbaik:", best_distance)


print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {[0] + route.tolist() + [0]}, Total Jarak Tempuh: {objective_function([0] + route.tolist() + [0], locations)}")  # Menambahkan depot di awal dan akhir rute
# Out:
# Iterasi 100:
# Kendaraan 1: Nilai Fitness = 4.035973698315788
# Kendaraan 2: Nilai Fitness = 3.77962420876592
# Kendaraan 3: Nilai Fitness = 3.448904692381411
# Kendaraan 4: Nilai Fitness = 3.4895174571075067
# Iterasi 200:
# Kendaraan 1: Nilai Fitness = 3.656397840206084
# Kendaraan 2: Nilai Fitness = 4.569619441157952
# Kendaraan 3: Nilai Fitness = 3.448904692381411
# Kendaraan 4: Nilai Fitness = 3.4895174571075067
# Iterasi 300:
# Kendaraan 1: Nilai Fitness = 3.4731529144584137
# Kendaraan 2: Nilai Fitness = 3.2623326381429014
# Kendaraan 3: Nilai Fitness = 3.448904692381411
# Kendaraan 4: Nilai Fitness = 4.725719322436584
# Iterasi 400:
# Kendaraan 1: Nilai Fitness = 4.710211094694971
# Kendaraan 2: Nilai Fitness = 3.2623326381429014
# Kendaraan 3: Nilai Fitness = 3.448904692381411
# Kendaraan 4: Nilai Fitness = 3.306973240315611
# Iterasi 500:
# Kendaraan 1: Nilai Fitness = 5.5486806176154655
# Kendaraan 2: Nilai Fitness = 3.2623326381429014
# ...

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    # Menambahkan jarak kembali ke depot
    total_distance += distance(locations[route[-1]], locations[0])
    return total_distance

def calculate_route_distance(route, locations):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += distance(locations[route[i]], locations[route[i+1]])
    # Menambahkan jarak kembali ke depot
    total_distance += distance(locations[route[-1]], locations[0])
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations - 1) + 1 for _ in range(num_routes)]  # Hindari depot di awal
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations):
    new_fitness = objective_function(route, locations)
    worst_idx = np.argmax([objective_function(p, locations) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations)
                print(f"Kendaraan {idx+1}: Nilai Fitness = {route_distance}")
    return best_route, population

num_iterations = 500
num_routes = 4
num_locations = 11
locations = np.random.rand(num_locations, 2)

best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations)

best_route_distance = calculate_route_distance(best_route, locations)  # Hitung total jarak tempuh untuk rute terbaik

print("\nRute Terbaik:", [0] + best_route.tolist() + [0])  # Menambahkan depot di awal dan akhir rute
print("Total Jarak Tempuh Rute Terbaik:", best_route_distance)

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    route_distance = calculate_route_distance(route, locations)  # Hitung total jarak tempuh untuk setiap rute
    print(f"Kendaraan {idx+1}: {[0] + route.tolist() + [0]}, Total Jarak Tempuh: {route_distance}")  # Menambahkan depot di awal dan akhir rute
# Out:
# Iterasi 100:
# Kendaraan 1: Nilai Fitness = 3.9523927638668384
# Kendaraan 2: Nilai Fitness = 3.6031453918676304
# Kendaraan 3: Nilai Fitness = 5.736352135551026
# Kendaraan 4: Nilai Fitness = 3.539256408743006
# Iterasi 200:
# Kendaraan 1: Nilai Fitness = 4.895121709205807
# Kendaraan 2: Nilai Fitness = 3.6031453918676304
# Kendaraan 3: Nilai Fitness = 3.641865799092173
# Kendaraan 4: Nilai Fitness = 3.539256408743006
# Iterasi 300:
# Kendaraan 1: Nilai Fitness = 3.4772949481810866
# Kendaraan 2: Nilai Fitness = 3.6031453918676304
# Kendaraan 3: Nilai Fitness = 5.697654836404697
# Kendaraan 4: Nilai Fitness = 3.539256408743006
# Iterasi 400:
# Kendaraan 1: Nilai Fitness = 3.4772949481810866
# Kendaraan 2: Nilai Fitness = 3.6031453918676304
# Kendaraan 3: Nilai Fitness = 4.8817435280245824
# Kendaraan 4: Nilai Fitness = 3.539256408743006
# Iterasi 500:
# Kendaraan 1: Nilai Fitness = 3.4772949481810866
# Kendaraan 2: Nilai Fitness = 3.6031453918676304
# ...

# %%
# !pip install ortools

# %%
"""Simple Pickup Delivery Problem (PDP)."""

from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp


def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data["distance_matrix"] = [
        # fmt: off
      [0, 548, 776, 696, 582, 274, 502, 194, 308, 194, 536, 502, 388, 354, 468, 776, 662],
      [548, 0, 684, 308, 194, 502, 730, 354, 696, 742, 1084, 594, 480, 674, 1016, 868, 1210],
      [776, 684, 0, 992, 878, 502, 274, 810, 468, 742, 400, 1278, 1164, 1130, 788, 1552, 754],
      [696, 308, 992, 0, 114, 650, 878, 502, 844, 890, 1232, 514, 628, 822, 1164, 560, 1358],
      [582, 194, 878, 114, 0, 536, 764, 388, 730, 776, 1118, 400, 514, 708, 1050, 674, 1244],
      [274, 502, 502, 650, 536, 0, 228, 308, 194, 240, 582, 776, 662, 628, 514, 1050, 708],
      [502, 730, 274, 878, 764, 228, 0, 536, 194, 468, 354, 1004, 890, 856, 514, 1278, 480],
      [194, 354, 810, 502, 388, 308, 536, 0, 342, 388, 730, 468, 354, 320, 662, 742, 856],
      [308, 696, 468, 844, 730, 194, 194, 342, 0, 274, 388, 810, 696, 662, 320, 1084, 514],
      [194, 742, 742, 890, 776, 240, 468, 388, 274, 0, 342, 536, 422, 388, 274, 810, 468],
      [536, 1084, 400, 1232, 1118, 582, 354, 730, 388, 342, 0, 878, 764, 730, 388, 1152, 354],
      [502, 594, 1278, 514, 400, 776, 1004, 468, 810, 536, 878, 0, 114, 308, 650, 274, 844],
      [388, 480, 1164, 628, 514, 662, 890, 354, 696, 422, 764, 114, 0, 194, 536, 388, 730],
      [354, 674, 1130, 822, 708, 628, 856, 320, 662, 388, 730, 308, 194, 0, 342, 422, 536],
      [468, 1016, 788, 1164, 1050, 514, 514, 662, 320, 274, 388, 650, 536, 342, 0, 764, 194],
      [776, 868, 1552, 560, 674, 1050, 1278, 742, 1084, 810, 1152, 274, 388, 422, 764, 0, 798],
      [662, 1210, 754, 1358, 1244, 708, 480, 856, 514, 468, 354, 844, 730, 536, 194, 798, 0],
        # fmt: on
    ]
    data["pickups_deliveries"] = [
        [1, 6],
        [2, 10],
        [4, 3],
        [5, 9],
        [7, 8],
        [15, 11],
        [13, 12],
        [16, 14],
    ]
    data["num_vehicles"] = 4
    data["depot"] = 0
    return data


def print_solution(data, manager, routing, solution):
    """Prints solution on console."""
    print(f"Objective: {solution.ObjectiveValue()}")
    total_distance = 0
    for vehicle_id in range(data["num_vehicles"]):
        index = routing.Start(vehicle_id)
        plan_output = f"Route for vehicle {vehicle_id}:\n"
        route_distance = 0
        while not routing.IsEnd(index):
            plan_output += f" {manager.IndexToNode(index)} -> "
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id
            )
        plan_output += f"{manager.IndexToNode(index)}\n"
        plan_output += f"Distance of the route: {route_distance}m\n"
        print(plan_output)
        total_distance += route_distance
    print(f"Total Distance of all routes: {total_distance}m")


def main():
    """Entry point of the program."""
    # Instantiate the data problem.
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(
        len(data["distance_matrix"]), data["num_vehicles"], data["depot"]
    )

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    # Define cost of each arc.
    def distance_callback(from_index, to_index):
        """Returns the manhattan distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data["distance_matrix"][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Add Distance constraint.
    dimension_name = "Distance"
    routing.AddDimension(
        transit_callback_index,
        0,  # no slack
        3000,  # vehicle maximum travel distance
        True,  # start cumul to zero
        dimension_name,
    )
    distance_dimension = routing.GetDimensionOrDie(dimension_name)
    distance_dimension.SetGlobalSpanCostCoefficient(100)

    # Define Transportation Requests.
    for request in data["pickups_deliveries"]:
        pickup_index = manager.NodeToIndex(request[0])
        delivery_index = manager.NodeToIndex(request[1])
        routing.AddPickupAndDelivery(pickup_index, delivery_index)
        routing.solver().Add(
            routing.VehicleVar(pickup_index) == routing.VehicleVar(delivery_index)
        )
        routing.solver().Add(
            distance_dimension.CumulVar(pickup_index)
            <= distance_dimension.CumulVar(delivery_index)
        )

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PARALLEL_CHEAPEST_INSERTION
    )

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution)


if __name__ == "__main__":
    main()
# Out:
# Objective: 226116
# Route for vehicle 0:
#  0 ->  13 ->  15 ->  11 ->  12 -> 0
# Distance of the route: 1552m
#
# Route for vehicle 1:
#  0 ->  5 ->  2 ->  10 ->  16 ->  14 ->  9 -> 0
# Distance of the route: 2192m
#
# Route for vehicle 2:
#  0 ->  4 ->  3 -> 0
# Distance of the route: 1392m
#
# Route for vehicle 3:
#  0 ->  7 ->  1 ->  6 ->  8 -> 0
# Distance of the route: 1780m
#
# Total Distance of all routes: 6916m

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations, pickups_deliveries):
    total_distance = 0
    current_location = 0  # Awalnya di depot
    for action in route:
        if action >= len(locations):  # Delivery
            delivery_location = action - len(locations)
            total_distance += distance(locations[current_location], locations[delivery_location])
            current_location = delivery_location
        else:  # Pickup
            total_distance += distance(locations[current_location], locations[action])
            current_location = action
    # Kembali ke depot setelah selesai semua pickup dan delivery
    total_distance += distance(locations[current_location], locations[0])
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations, pickups_deliveries):
    new_fitness = objective_function(route, locations, pickups_deliveries)
    worst_idx = np.argmax([objective_function(p, locations, pickups_deliveries) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations, pickups_deliveries)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations, pickups_deliveries)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations, pickups_deliveries)
                print(f"Kendaraan {idx+1}: Nilai Fitness = {route_distance}")
    return best_route, population

# Data
num_iterations = 500
num_routes = 4
num_locations = 9  # Jumlah lokasi, termasuk depot
locations = np.random.rand(num_locations, 2)
pickups_deliveries = [
    [1, 6],
    [4, 3],
    [5, 2],
    [7, 8],
]

# Panggil fungsi artificial_bee_colony
best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries)

# Cetak rute terbaik dan total jarak tempuh
print("\nRute Terbaik:", best_route)
print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations, pickups_deliveries))

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    print(f"Kendaraan {idx+1}: {route}, Total Jarak Tempuh: {objective_function(route, locations, pickups_deliveries)}")
# Out:
# Iterasi 100:
# Kendaraan 1: Nilai Fitness = 3.597341381124782
# Kendaraan 2: Nilai Fitness = 5.622927915612484
# Kendaraan 3: Nilai Fitness = 3.5389544201585887
# Kendaraan 4: Nilai Fitness = 3.404823562854687
# Iterasi 200:
# Kendaraan 1: Nilai Fitness = 4.134205157215364
# Kendaraan 2: Nilai Fitness = 3.5016223482764364
# Kendaraan 3: Nilai Fitness = 3.5389544201585887
# Kendaraan 4: Nilai Fitness = 3.404823562854687
# Iterasi 300:
# Kendaraan 1: Nilai Fitness = 4.665112816984886
# Kendaraan 2: Nilai Fitness = 3.5016223482764364
# Kendaraan 3: Nilai Fitness = 3.5389544201585887
# Kendaraan 4: Nilai Fitness = 3.404823562854687
# Iterasi 400:
# Kendaraan 1: Nilai Fitness = 4.2555430981935025
# Kendaraan 2: Nilai Fitness = 3.5016223482764364
# Kendaraan 3: Nilai Fitness = 3.4090677569246437
# Kendaraan 4: Nilai Fitness = 3.404823562854687
# Iterasi 500:
# Kendaraan 1: Nilai Fitness = 3.3882439472134496
# Kendaraan 2: Nilai Fitness = 6.547101915356928
# ...

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations, pickups_deliveries):
    total_distance = 0
    current_location = 0  # Awalnya di depot
    for action in route:
        if action >= len(locations):  # Delivery
            delivery_location = action - len(locations)
            total_distance += distance(locations[current_location], locations[delivery_location])
            current_location = delivery_location
        else:  # Pickup
            total_distance += distance(locations[current_location], locations[action])
            current_location = action
    # Kembali ke depot setelah selesai semua pickup dan delivery
    total_distance += distance(locations[current_location], locations[0])
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations, pickups_deliveries):
    new_fitness = objective_function(route, locations, pickups_deliveries)
    worst_idx = np.argmax([objective_function(p, locations, pickups_deliveries) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations, pickups_deliveries)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations, pickups_deliveries)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations, pickups_deliveries)
                print(f"Kendaraan {idx+1}: Nilai Fitness = {route_distance}")
    return best_route, population

# Data
num_iterations = 500
num_routes = 4
num_locations = 9  # Jumlah lokasi, termasuk depot
locations = np.random.rand(num_locations, 2)
pickups_deliveries = [
    [1, 6],
    [4, 3],
    [5, 2],
    [7, 8],
]

# Panggil fungsi artificial_bee_colony
best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries)

# Hitung total jarak tempuh rute terbaik
best_route_distance = objective_function(best_route, locations, pickups_deliveries)

# Cetak rute terbaik dan total jarak tempuh
print("\nRute Terbaik:", [0] + best_route.tolist() + [0])  # Menambahkan depot di awal dan akhir rute
print("Total Jarak Tempuh Rute Terbaik:", best_route_distance)

print("\nRute Terbaik Setiap Kendaraan:")
for idx, route in enumerate(all_routes):
    route_distance = objective_function(route, locations, pickups_deliveries)  # Hitung total jarak tempuh untuk setiap rute
    print(f"Kendaraan {idx+1}: {[0] + route.tolist() + [0]}, Total Jarak Tempuh: {route_distance}")  # Menambahkan depot di awal dan akhir rute
# Out:
# Iterasi 100:
# Kendaraan 1: Nilai Fitness = 3.737459148114233
# Kendaraan 2: Nilai Fitness = 3.8761609551296403
# Kendaraan 3: Nilai Fitness = 7.54571426139935
# Kendaraan 4: Nilai Fitness = 3.9301093332650217
# Iterasi 200:
# Kendaraan 1: Nilai Fitness = 3.737459148114233
# Kendaraan 2: Nilai Fitness = 3.8761609551296403
# Kendaraan 3: Nilai Fitness = 3.887382317289143
# Kendaraan 4: Nilai Fitness = 6.55235536367609
# Iterasi 300:
# Kendaraan 1: Nilai Fitness = 3.737459148114233
# Kendaraan 2: Nilai Fitness = 3.8761609551296403
# Kendaraan 3: Nilai Fitness = 6.061066453690517
# Kendaraan 4: Nilai Fitness = 3.8636361608877587
# Iterasi 400:
# Kendaraan 1: Nilai Fitness = 3.737459148114233
# Kendaraan 2: Nilai Fitness = 5.900512395620007
# Kendaraan 3: Nilai Fitness = 3.7191238184663185
# Kendaraan 4: Nilai Fitness = 3.8636361608877587
# Iterasi 500:
# Kendaraan 1: Nilai Fitness = 3.737459148114233
# Kendaraan 2: Nilai Fitness = 3.7032633268272974
# ...

# %%
import numpy as np
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp


def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data["distance_matrix"] = [
        # fmt: off
        [0, 548, 776, 696, 582, 274, 502, 194, 308, 194, 536, 502, 388, 354, 468, 776, 662],
        [548, 0, 684, 308, 194, 502, 730, 354, 696, 742, 1084, 594, 480, 674, 1016, 868, 1210],
        [776, 684, 0, 992, 878, 502, 274, 810, 468, 742, 400, 1278, 1164, 1130, 788, 1552, 754],
        [696, 308, 992, 0, 114, 650, 878, 502, 844, 890, 1232, 514, 628, 822, 1164, 560, 1358],
        [582, 194, 878, 114, 0, 536, 764, 388, 730, 776, 1118, 400, 514, 708, 1050, 674, 1244],
        [274, 502, 502, 650, 536, 0, 228, 308, 194, 240, 582, 776, 662, 628, 514, 1050, 708],
        [502, 730, 274, 878, 764, 228, 0, 536, 194, 468, 354, 1004, 890, 856, 514, 1278, 480],
        [194, 354, 810, 502, 388, 308, 536, 0, 342, 388, 730, 468, 354, 320, 662, 742, 856],
        [308, 696, 468, 844, 730, 194, 194, 342, 0, 274, 388, 810, 696, 662, 320, 1084, 514],
        [194, 742, 742, 890, 776, 240, 468, 388, 274, 0, 342, 536, 422, 388, 274, 810, 468],
        [536, 1084, 400, 1232, 1118, 582, 354, 730, 388, 342, 0, 878, 764, 730, 388, 1152, 354],
        [502, 594, 1278, 514, 400, 776, 1004, 468, 810, 536, 878, 0, 114, 308, 650, 274, 844],
        [388, 480, 1164, 628, 514, 662, 890, 354, 696, 422, 764, 114, 0, 194, 536, 388, 730],
        [354, 674, 1130, 822, 708, 628, 856, 320, 662, 388, 730, 308, 194, 0, 342, 422, 536],
        [468, 1016, 788, 1164, 1050, 514, 514, 662, 320, 274, 388, 650, 536, 342, 0, 764, 194],
        [776, 868, 1552, 560, 674, 1050, 1278, 742, 1084, 810, 1152, 274, 388, 422, 764, 0, 798],
        [662, 1210, 754, 1358, 1244, 708, 480, 856, 514, 468, 354, 844, 730, 536, 194, 798, 0],
        # fmt: on
    ]
    data["pickups_deliveries"] = [
        [1, 6],
        [2, 10],
        [4, 3],
        [5, 9],
        [7, 8],
        [15, 11],
        [13, 12],
        [16, 14],
    ]
    data["num_vehicles"] = 4
    data["depot"] = 0
    return data


def distance_callback(from_index, to_index):
    """Returns the manhattan distance between the two nodes."""
    # Convert from routing variable Index to distance matrix NodeIndex.
    from_node = manager.IndexToNode(from_index)
    to_node = manager.IndexToNode(to_index)
    return data["distance_matrix"][from_node][to_node]



def print_solution(manager, routing, solution):
    """Prints solution on console."""
    print(f"Objective: {solution.ObjectiveValue()}")
    total_distance = 0
    for vehicle_id in range(data["num_vehicles"]):
        index = routing.Start(vehicle_id)
        plan_output = f"Route for vehicle {vehicle_id}:\n"
        route_distance = 0
        while not routing.IsEnd(index):
            plan_output += f" {manager.IndexToNode(index)} -> "
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id
            )
        plan_output += f"{manager.IndexToNode(index)}\n"
        plan_output += f"Distance of the route: {route_distance}m\n"
        print(plan_output)
        total_distance += route_distance
    print(f"Total Distance of all routes: {total_distance}m")


def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population


def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]


def explore_route(route):
    return np.random.permutation(route)


def update_population(population, route, locations, pickups_deliveries):
    new_fitness = objective_function(route, locations, pickups_deliveries)
    worst_idx = np.argmax([objective_function(p, locations, pickups_deliveries) for p in population])
    population[worst_idx] = route
    return population


def artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations, pickups_deliveries)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations, pickups_deliveries)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations, pickups_deliveries)
                print(f"Kendaraan {idx+1}: Nilai Fitness = {route_distance}")
    return best_route, population


def main():
    # Instantiate the data problem.
    data = create_data_model()

    # Panggil fungsi artificial_bee_colony
    best_route, all_routes = artificial_bee_colony(num_iterations=500, num_routes=data["num_vehicles"],
                                                    num_locations=len(data["distance_matrix"]),
                                                    locations=data["distance_matrix"], pickups_deliveries=data["pickups_deliveries"])

    # Hitung total jarak tempuh rute terbaik
    best_route_distance = objective_function(best_route, data["distance_matrix"], data["pickups_deliveries"])

    # Cetak rute terbaik dan total jarak tempuh
    print("\nRute Terbaik:", [0] + best_route.tolist() + [0])  # Menambahkan depot di awal dan akhir rute
    print("Total Jarak Tempuh Rute Terbaik:", best_route_distance)

    print("\nRute Terbaik Setiap Kendaraan:")
    for idx, route in enumerate(all_routes):
        route_distance = objective_function(route, data["distance_matrix"], data["pickups_deliveries"])
        print(f"Kendaraan {idx+1}: {[0] + route.tolist() + [0]}, Total Jarak Tempuh: {route_distance}")


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-77ab80c703bd> in <cell line: 141>()
#     140
#     141 if __name__ == "__main__":
# --> 142     main()
#
# <ipython-input-29-77ab80c703bd> in main()
#     122
#     123     # Panggil fungsi artificial_bee_colony
# --> 124     best_route, all_routes = artificial_bee_colony(num_iterations=500, num_routes=data["num_vehicles"],
#     125                                                     num_locations=len(data["distance_matrix"]),
#     126                                                     locations=data["distance_matrix"], pickups_deliveries=data["pickups_deliveries"])
#
# <ipython-input-29-77ab80c703bd> in artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries)
#     102             exploratory_route = select_exploratory_route(population)
# ...

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations, pickups_deliveries):
    total_distance = 0
    current_location = 0  # Awalnya di depot
    for action in route:
        if action >= len(locations):  # Delivery
            delivery_location = pickups_deliveries[action - len(locations)][1]
            total_distance += distance(locations[current_location], locations[delivery_location])
            current_location = delivery_location
        else:  # Pickup
            pickup_location = action
            total_distance += distance(locations[current_location], locations[pickup_location])
            current_location = pickup_location
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations, pickups_deliveries):
    new_fitness = objective_function(route, locations, pickups_deliveries)
    worst_idx = np.argmax([objective_function(p, locations, pickups_deliveries) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations, pickups_deliveries)  # Perubahan di sini
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations, pickups_deliveries)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations, pickups_deliveries)
                print(f"Kendaraan {idx+1}: Nilai Fitness = {route_distance}")
    return best_route, population

def main():
    num_iterations = 500
    num_routes = 4
    num_locations = 11
    locations = np.random.rand(num_locations, 2)
    pickups_deliveries = [
        [1, 6],
        [4, 3],
        [5, 2],
        [7, 8],
    ]

    best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries)
    print("\nRute Terbaik:", [0] + best_route.tolist() + [0])  # Menambahkan depot di awal dan akhir rute
    print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations, pickups_deliveries))

    print("\nRute Terbaik Setiap Kendaraan:")
    for idx, route in enumerate(all_routes):
        route_distance = objective_function(route, locations, pickups_deliveries)
        print(f"Kendaraan {idx+1}: {[0] + route.tolist() + [0]}, Total Jarak Tempuh: {route_distance}")


if __name__ == "__main__":
    main()
# Out:
# Iterasi 100:
# Kendaraan 1: Nilai Fitness = 3.990247099488516
# Kendaraan 2: Nilai Fitness = 3.993774450935425
# Kendaraan 3: Nilai Fitness = 4.540955944162331
# Kendaraan 4: Nilai Fitness = 6.814332148167679
# Iterasi 200:
# Kendaraan 1: Nilai Fitness = 3.990247099488516
# Kendaraan 2: Nilai Fitness = 3.993774450935425
# Kendaraan 3: Nilai Fitness = 6.719255738040263
# Kendaraan 4: Nilai Fitness = 4.007950528590635
# Iterasi 300:
# Kendaraan 1: Nilai Fitness = 3.990247099488516
# Kendaraan 2: Nilai Fitness = 3.993774450935425
# Kendaraan 3: Nilai Fitness = 3.8880082088091115
# Kendaraan 4: Nilai Fitness = 7.087595823078829
# Iterasi 400:
# Kendaraan 1: Nilai Fitness = 3.990247099488516
# Kendaraan 2: Nilai Fitness = 3.993774450935425
# Kendaraan 3: Nilai Fitness = 3.8880082088091115
# Kendaraan 4: Nilai Fitness = 5.348328946225031
# Iterasi 500:
# Kendaraan 1: Nilai Fitness = 3.990247099488516
# Kendaraan 2: Nilai Fitness = 3.993774450935425
# ...

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations, pickups_deliveries):
    total_distance = 0
    current_location = 0  # Awalnya di depot
    for action in route:
        if action >= len(locations):  # Delivery
            delivery_location = pickups_deliveries[action - len(locations)][1]
            total_distance += distance(locations[current_location], locations[delivery_location])
            current_location = delivery_location
        else:  # Pickup
            pickup_location = action
            total_distance += distance(locations[current_location], locations[pickup_location])
            current_location = pickup_location
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations, pickups_deliveries):
    new_fitness = objective_function(route, locations, pickups_deliveries)
    worst_idx = np.argmax([objective_function(p, locations, pickups_deliveries) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations, pickups_deliveries)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations, pickups_deliveries)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations, pickups_deliveries)
                print(f"Kendaraan {idx+1}: Nilai Fitness = {route_distance}")
    return best_route, population

def main():
    num_iterations = 500
    num_routes = 4
    num_locations = 11
    locations = np.random.rand(num_locations, 2)
    pickups_deliveries = [
        [1, 6],
        [4, 3],
        [5, 2],
        [7, 8],
    ]

    best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries)
    print("\nRute Terbaik:", [0] + best_route.tolist() + [0])  # Menambahkan depot di awal dan akhir rute
    print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations, pickups_deliveries))

    print("\nRute Terbaik Setiap Kendaraan:")
    for idx, route in enumerate(all_routes):
        route_distance = objective_function(route, locations, pickups_deliveries)
        print(f"Kendaraan {idx+1}: {[0] + route.tolist() + [0]}, Total Jarak Tempuh: {route_distance}")


if __name__ == "__main__":
    main()
# Out:
# Iterasi 100:
# Kendaraan 1: Nilai Fitness = 5.224145149949596
# Kendaraan 2: Nilai Fitness = 3.3624511436473705
# Kendaraan 3: Nilai Fitness = 3.692975765810578
# Kendaraan 4: Nilai Fitness = 3.6973404908383243
# Iterasi 200:
# Kendaraan 1: Nilai Fitness = 3.4438530831250436
# Kendaraan 2: Nilai Fitness = 3.3624511436473705
# Kendaraan 3: Nilai Fitness = 6.022477332421316
# Kendaraan 4: Nilai Fitness = 3.4996161935282406
# Iterasi 300:
# Kendaraan 1: Nilai Fitness = 3.4438530831250436
# Kendaraan 2: Nilai Fitness = 3.3624511436473705
# Kendaraan 3: Nilai Fitness = 5.631879152386196
# Kendaraan 4: Nilai Fitness = 3.4996161935282406
# Iterasi 400:
# Kendaraan 1: Nilai Fitness = 3.4438530831250436
# Kendaraan 2: Nilai Fitness = 3.3624511436473705
# Kendaraan 3: Nilai Fitness = 5.554577914025339
# Kendaraan 4: Nilai Fitness = 3.4996161935282406
# Iterasi 500:
# Kendaraan 1: Nilai Fitness = 3.4438530831250436
# Kendaraan 2: Nilai Fitness = 3.3624511436473705
# ...

# %%
import numpy as np

def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

def objective_function(route, locations, pickups_deliveries):
    total_distance = 0
    current_location = 0  # Awalnya di depot
    for action in route:
        if action >= len(locations):  # Delivery
            delivery_location = pickups_deliveries[action - len(locations)][1]
            total_distance += distance(locations[current_location], locations[delivery_location])
            current_location = delivery_location
        else:  # Pickup
            pickup_location = action
            total_distance += distance(locations[current_location], locations[pickup_location])
            current_location = pickup_location
    total_distance += distance(locations[current_location], locations[0])  # Kembali ke depot
    return total_distance

def initialize_population(num_routes, num_locations):
    population = [np.random.permutation(num_locations) for _ in range(num_routes)]
    return population

def select_exploratory_route(population):
    return population[np.random.randint(0, len(population))]

def explore_route(route):
    return np.random.permutation(route)

def update_population(population, route, locations, pickups_deliveries):
    new_fitness = objective_function(route, locations, pickups_deliveries)
    worst_idx = np.argmax([objective_function(p, locations, pickups_deliveries) for p in population])
    population[worst_idx] = route
    return population

def artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries):
    population = initialize_population(num_routes, num_locations)
    best_route = None
    best_distance = float('inf')
    all_routes = []
    for iteration in range(num_iterations):
        for i, route in enumerate(population):
            exploratory_route = select_exploratory_route(population)
            new_route = explore_route(exploratory_route)
            population = update_population(population, new_route, locations, pickups_deliveries)
        # Memperbarui rute terbaik setiap iterasi
        for route in population:
            route_distance = objective_function(route, locations, pickups_deliveries)
            if route_distance < best_distance:
                best_distance = route_distance
                best_route = route
        if (iteration + 1) % 100 == 0:
            print(f"Iterasi {iteration + 1}:")
            for idx, route in enumerate(population):
                route_distance = objective_function(route, locations, pickups_deliveries)
                print(f"Kendaraan {idx+1}: {[0] + route.tolist() + [0]}, Total Jarak Tempuh: {route_distance}")
        all_routes.append(population)
    return best_route, all_routes

def main():
    num_iterations = 500
    num_routes = 4
    num_locations = 11
    locations = np.random.rand(num_locations, 2)
    pickups_deliveries = [
        [1, 6],
        [4, 3],
        [5, 2],
        [7, 8],
    ]

    best_route, all_routes = artificial_bee_colony(num_iterations, num_routes, num_locations, locations, pickups_deliveries)
    print("\nRute Terbaik:", [0] + best_route.tolist() + [0])  # Menambahkan depot di awal dan akhir rute
    print("Total Jarak Tempuh Rute Terbaik:", objective_function(best_route, locations, pickups_deliveries))

    print("\nRute Terbaik Setiap Kendaraan:")
    for idx, routes in enumerate(all_routes):
        print(f"Kendaraan {idx+1}:")
        for route in routes:
            route_distance = objective_function(route, locations, pickups_deliveries)  # Hitung total jarak tempuh untuk setiap rute
            print(f"{[0] + route.tolist() + [0]}: {route_distance}")

if __name__ == "__main__":
    main()
# Out:
# Iterasi 100:
# Kendaraan 1: [0, 0, 9, 6, 4, 5, 1, 8, 3, 2, 10, 7, 0], Total Jarak Tempuh: 4.0267538624736465
# Kendaraan 2: [0, 5, 9, 3, 7, 8, 2, 10, 6, 4, 1, 0, 0], Total Jarak Tempuh: 4.116860494560624
# Kendaraan 3: [0, 3, 1, 5, 7, 2, 0, 9, 6, 8, 4, 10, 0], Total Jarak Tempuh: 5.733169233650485
# Kendaraan 4: [0, 9, 4, 2, 8, 3, 6, 10, 7, 1, 5, 0, 0], Total Jarak Tempuh: 4.263150921687499
# Iterasi 200:
# Kendaraan 1: [0, 0, 9, 6, 4, 5, 1, 8, 3, 2, 10, 7, 0], Total Jarak Tempuh: 4.0267538624736465
# Kendaraan 2: [0, 5, 9, 3, 7, 8, 2, 10, 6, 4, 1, 0, 0], Total Jarak Tempuh: 4.116860494560624
# Kendaraan 3: [0, 9, 7, 10, 4, 6, 3, 8, 2, 1, 5, 0, 0], Total Jarak Tempuh: 4.170465360495253
# Kendaraan 4: [0, 5, 7, 6, 10, 3, 9, 1, 4, 2, 0, 8, 0], Total Jarak Tempuh: 6.918216616234133
# Iterasi 300:
# Kendaraan 1: [0, 0, 9, 6, 4, 5, 1, 8, 3, 2, 10, 7, 0], Total Jarak Tempuh: 4.0267538624736465
# Kendaraan 2: [0, 5, 9, 3, 7, 8, 2, 10, 6, 4, 1, 0, 0], Total Jarak Tempuh: 4.116860494560624
# ...
